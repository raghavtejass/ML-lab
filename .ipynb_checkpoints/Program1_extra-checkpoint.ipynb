# %%
import pandas as pd
import csv

print("Name: S Raghav Tejas")
print("USN: 1CR17CS119")

traindata=pd.read_csv("poisonous.csv")

cols=traindata.shape[1]
rows=traindata.shape[0]
print(cols)
print(rows)

print("The training data is as follows:")
print(traindata)
print("\nThe most general Hypothesis : ['?','?','?','?','?','?']\n")
h=['0','0','0','0','0','0']
print("The most specific hypothesis : ",h,"\n")

positivesample=[]
negativesample=[]

for i in range(rows):
    trainsample=[]
    trainsample.append(traindata.color[i])
    trainsample.append(traindata.toughness[i])
    trainsample.append(traindata.fungus[i])
    trainsample.append(traindata.appearence[i])
    if(traindata.poisonous[i]!='NO'):
        positivesample.append(trainsample)
    else:
        negativesample.append(trainsample)
        
print("positive samples are: \n",positivesample)
print("negative samples are: \n",negativesample)

for i in range(len(positivesample)):
    for j in range(cols-1):
        if(h[j]=='0'):
            h[j]=positivesample[i][j]
        if(h[j]!=positivesample[i][j]):
            h[j]='?'
        else:
            h[j]=positivesample[i][j]
        print("\n For training example ",i," the hypothesis is ",h)
print("\nThe maximally specific Hypothesis for a given training example :\n")
print(h)
# Out:
# Name: S Raghav Tejas
# USN: 1CR17CS119
# 5
# 7
# The training data is as follows:
#     color toughness fungus appearence poisonous
# 0   green      hard     no   wrinkled       yes
# 1   green      hard    yes     smooth        no
# 2   brown      soft     no   wrinkled        no
# 3  orange      hard     no   wrinkled       yes
# 4   green      soft    yes     smooth       yes
# 5   green      hard    yes   wrinkled       yes
# 6  orange      hard     no   wrinkled       yes
#
# The most general Hypothesis : ['?','?','?','?','?','?']
#
# The most specific hypothesis :  ['0', '0', '0', '0', '0', '0']
#
# positive samples are:
#  [['green', 'hard', 'no', 'wrinkled'], ['green', 'hard', 'yes', 'smooth'], ['brown', 'soft', 'no', 'wrinkled'], ['orange', 'hard', 'no', 'wrinkled'], ['green', 'soft', 'yes', 'smooth'], ['green', 'hard', 'yes', 'wrinkled'], ['orange', 'hard', 'no', 'wrinkled']]
# negative samples are:
#  []
#
#  For training example  0  the hypothesis is  ['green', '0', '0', '0', '0', '0']
#
#  For training example  0  the hypothesis is  ['green', 'hard', '0', '0', '0', '0']
#
#  For training example  0  the hypothesis is  ['green', 'hard', 'no', '0', '0', '0']
#
#  For training example  0  the hypothesis is  ['green', 'hard', 'no', 'wrinkled', '0', '0']
#
#  For training example  1  the hypothesis is  ['green', 'hard', 'no', 'wrinkled', '0', '0']
#
#  For training example  1  the hypothesis is  ['green', 'hard', 'no', 'wrinkled', '0', '0']
#
#  For training example  1  the hypothesis is  ['green', 'hard', '?', 'wrinkled', '0', '0']
#
#  For training example  1  the hypothesis is  ['green', 'hard', '?', '?', '0', '0']
#
#  For training example  2  the hypothesis is  ['?', 'hard', '?', '?', '0', '0']
#
#  For training example  2  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  2  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  2  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  3  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  3  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  3  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  3  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  4  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  4  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  4  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  4  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  5  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  5  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  5  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  5  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  6  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  6  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  6  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
#  For training example  6  the hypothesis is  ['?', '?', '?', '?', '0', '0']
#
# The maximally specific Hypothesis for a given training example :
#
# ['?', '?', '?', '?', '0', '0']
